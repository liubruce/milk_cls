# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import logging
from pathlib import Path
from dotenv import find_dotenv, load_dotenv
import pandas as pd
import os
import os.path as osp
import skimage.io
import skimage.color
import skimage.filters
from PIL import Image

from src.features.build_features import detect_outside_circle, detect_inner_ring

# %%
__file__ = os.path.abspath('')

project_dir = Path(__file__).resolve()

print(project_dir)


p_dn = Path(str(project_dir) + '/../data/raw/dn').resolve()
p_pc = Path(str(project_dir) + '/../data/raw/pc').resolve()
# Out:
# /Users/bruceliu/projects/milk_cls/notebooks

# %%
circle_info = []
for x in p_dn.iterdir():
        # print(x)
    circles, num_cirlces = detect_outside_circle(str(x))
    circle_info.append([circles, num_cirlces, str(x)])
#     detect_inner_ring(str(x))
    # exit(0)
for x in p_pc.iterdir():
        # print(x)
    circles, num_cirlces = detect_outside_circle(str(x))
    circle_info.append([circles, num_cirlces, str(x)])
#     detect_inner_ring(str(x))

print(circle_info)
# Out:
# /Users/bruceliu/projects/milk_cls/notebooks
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# [[array([[[664.5, 480.5, 192.7]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DBM_90_13Jan_DN.jpg'], [array([[[1151.5,  926.5,  445.2]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DN5_C1.bmp'], [array([[[1311.5, 1161.5,  547.3]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DN1_C1.bmp'], [array([[[641.5, 411.5, 179.2]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/LBM_90A_5Jan_DN.jpg'], [array([[[1338.5, 1077.5,  418.2]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DBM_50uL_70C_C1_a.bmp'], [array([[[1341.5, 1043.5,  447.5]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DBM_50uL_70C_C1_c.bmp'], [array([[[1381.5,  979.5,  538.6]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DBM_50uL_70C_C1_b.bmp'], [array([[[649.5, 437.5, 197.5]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/LBM_80_5Jan_DN.jpg'], [array([[[1145.5, 1122.5,  547.8]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DN3_C1.bmp'], [array([[[1272.5, 1032.5,  305.8]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DN6_C1.bmp'], [array([[[1275.5, 1034.5,  303.5]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DN6_C2.bmp'], [array([[[659.5, 518.5, 252. ]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DBM_80B_13Jan_DN.jpg'], [array([[[1049.5,  843.5,  534.8]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DN4_C1.bmp'], [array([[[1342.5, 1037.5,  444.8]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DBM_50uL_70C_C1_c2.bmp'], [array([[[1144.5, 1089.5,  461.6]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/220207a_C2.bmp'], [array([[[1384.5, 1186.5,  589.7]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/DN2_C1.bmp'], [array([[[1144.5, 1089.5,  461.6]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/dn/220207a_C1.bmp'], [array([[[576.5, 472.5, 472.7]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/LBM_70_5Jan_PC.jpg'], [array([[[1268.5, 1344.5,  500.6]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/220208e_C1.bmp'], [array([[[1160.5, 1292.5,  537.6]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/220208h_C1_500mA.bmp'], [array([[[631.5, 475.5, 479.6]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/LBM_70B_5Jan_PC.jpg'], [array([[[690.5, 550.5, 259.3]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/DBM_55_13Jan_PC.jpg'], [array([[[1096.5, 1155.5,  506.7]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/220207c_DBM_41C_C1.bmp'], [array([[[1063.5,  960.5,  528.6]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/220207d_DBM_41C_C1.bmp'], [array([[[1224.5,  968.5,  479.1]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/220208a_DBM_5uL_38C_C1.bmp'], [array([[[1323.5,  984.5,  458. ]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/220208c_C1_P2.bmp'], [array([[[1286.5,  851.5,  523.7]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/220208b_C1.bmp'], [array([[[1209.5,  985.5,  487.9]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/220208a_DBM_5uL_38C_C1_Photo 2.bmp'], [array([[[557.5, 479.5, 479.8]]], dtype=float32), 1, '/Users/bruceliu/projects/milk_cls/data/raw/pc/DBM_58_13Jan_PC.jpg']]

# %%
for x in p_dn.iterdir():
        # print(x)
#     circles, num_cirlces = detect_outside_circle(str(x))
#     circle_info.append([circles, num_cirlces, str(x)])
    detect_inner_ring(str(x))
    # exit(0)
for x in p_pc.iterdir():
        # print(x)
#     circles, num_cirlces = detect_outside_circle(str(x))
#     circle_info.append([circles, num_cirlces, str(x)])
    detect_inner_ring(str(x))

# print(circle_info)
# Out:
# Empty :  DBM_90_13Jan_DN.jpg
# /Users/bruceliu/projects/milk_cls/src/features/build_features.py:137: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   gray_image = skimage.color.rgb2gray(image)
# The number of circle is  1
# The number of circle is  1
# Empty :  LBM_90A_5Jan_DN.jpg
# The number of circle is  1
# The number of circle is  1
# Empty :  DBM_50uL_70C_C1_b.bmp
# Empty :  LBM_80_5Jan_DN.jpg
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# Empty :  DBM_80B_13Jan_DN.jpg
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# The number of circle is  1
# Empty :  LBM_70_5Jan_PC.jpg
# Empty :  220208e_C1.bmp
# Empty :  220208h_C1_500mA.bmp
# Empty :  LBM_70B_5Jan_PC.jpg
# Empty :  DBM_55_13Jan_PC.jpg
# Empty :  220207c_DBM_41C_C1.bmp
# Empty :  220207d_DBM_41C_C1.bmp
# Empty :  220208a_DBM_5uL_38C_C1.bmp
# The number of circle is  1
# Empty :  220208b_C1.bmp
# Empty :  220208a_DBM_5uL_38C_C1_Photo 2.bmp
# Empty :  DBM_58_13Jan_PC.jpg
